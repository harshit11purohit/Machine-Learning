# %%
list=[1,2,3,"harsh"]
list.append("""10"harsh""")
list.remove("harsh")
print(list)
# Out:
# [1, 2, 3, '10"harsh']

# %%
tupllee =(1,2,3,4,5,6,"hp")
print(tupllee[5])
type(tupllee[6])
# Out:
# 6
# str

# %%
x=("hp","np")
y=("kp","vp")
z=(x,y)
print(z)
# Out:
# (('hp', 'np'), ('kp', 'vp'))

# %%
sety={1,2,3,4,"hp","np",1,2,3}
z=len(sety)
sety.remove(3)
print(z)
print(sety)
# Out:
# 6
# {1, 2, 4, 'hp', 'np'}

# %%
dicto = { "name":"hi" , "class":18}
print(dicto["name"])
print(dicto["class"])
# Out:
# hi
# 18

# %%
strin={ }
ascii 
UnicodeDecodeError
a=2**16
print(a)
n=2**7
print(n)
# Out:
# 65536
# 128

# %%
stre= """i""m a student"""
print(stre)
# Out:
# i""m a student

# %%
for i in range(10,-1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2
# 0

# %%
str="harsitpu rohit"
print(str[::2])
#string immutable origal remai unchanged

print(len(str))
z=str.replace("s","n") # modifiaction off a string..replace subaarays
print(z)
# Out:
# hrip oi
# 14
# harnitpu rohit

# %%
str1="harshita"
z=str1.replace("a","b")
print(z)
print(str1)
# Out:
# hbrshitb
# harshita

# %%
mail=["\nhars","\nhit953","\ngmail.com"]
sorted(mail)
print(mail)
if "@" in mail:
    print("good")
else: print("false ")
# Out:
# ['\nhars', '\nhit953', '\ngmail.com']
# false

# %%
name ="harshitp"
greet= f"i am { name } , how are you "
print(greet)
# Out:
# i am harshitp , how are you

# %%
s=input("enter")
n=len(s)
def reversestring(s):
    if len(s) == 0: 
         return s
    else:
        return reversestring(s[1:]) + s[0]
print(reversestring(s))
# Out:
# ascrth

# %%
hp={"harshit"}
print(hp)
# Out:
# {'harshit'}

# %%
hp="helloworld"
len(hp)
hp.upper()
print(hp)
# Out:
# HELLOWORLD

# %%
hp="helloguys"
three=hp[0:3]
print(three)
# Out:
# hel

# %%
li=[1,2,3,4,5]
li.append(10)
print(li)
for i in range(0,5):
    print(i)
# Out:
# [1, 2, 3, 4, 5, 10]
# 0
# 1
# 2
# 3
# 4

# %%
x = ['a', 'b', 'c', 'd']
for i in range(1,2):
    print(x)
x[1]
# Out:
# ['a', 'b', 'c', 'd']
# 'b'

# %%
x=[10, 20, 30, 40, 50]
for i in range(::-1):
    print(x)
# Out:
#   Cell In[25], line 2
#     for i in range(::-1):
#                    ^
# SyntaxError: invalid syntax

# %%
x = [10, 20, 30, 40, 50]

# Looping over indices in reverse
for i in range(len(x)-1, -1, -1):
    print(x[i])
# Out:
# 50
# 40
# 30
# 20
# 10

# %%
tup=(1,2,3,4,5,6)
for i in range(len(tup)-2,len(tup)-1):
    print(tup[i])
# Out:
# 5

# %%
def greet(name, message):
    print(message, name)

greet("Alice","Good morning!")  # Good morning! Alice
#greet(message="Hello", name="Bob")            # Hello Bob
# Out:
# Good morning! Alice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
x,y=make_moons(n_samples=250,noise=.10)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
db=DBSCAN(eps=0.2)

# %%
db.fit(x_scaled)
db.labels_
# Out:
# array([ 0,  1,  1,  2,  0,  0,  3, -1,  4,  4,  2,  4,  2,  3,  2,  4,  1,
#         1,  1,  0,  1,  1,  1,  1,  1,  4,  1,  4,  4,  1,  3,  5,  2, -1,
#         0,  6,  2,  1,  0,  4,  4,  7,  5,  4,  2,  4,  3, -1,  1,  6,  1,
#         4,  6,  0, -1, -1,  0,  6,  1,  0,  1,  0,  6,  4, -1,  4,  4,  2,
#         4, -1,  3,  1,  4,  1,  4,  1,  4,  1,  4,  4,  5,  7,  4,  1,  1,
#         1,  4,  1,  4,  4,  1,  0,  8, -1,  2,  0,  4,  0,  4,  0,  3,  1,
#         4,  0,  2,  4,  0,  1,  4,  0,  4,  8,  4,  0,  4,  4,  5,  2,  1,
#         8,  4,  4,  3, -1,  2,  0,  1,  1,  1,  1,  1,  4,  4,  8,  1, -1,
#         8,  4, -1,  4,  4, -1,  2,  5,  0,  4,  4,  4,  4,  3, -1,  0,  3,
#         4,  1,  2,  2,  4,  2,  4,  4,  1,  4,  4,  7,  4, -1,  4,  1,  3,
#         8,  0, -1,  1,  5,  1,  0,  4,  0,  1,  4, -1,  1,  4,  8, -1,  4,
#         4,  4,  1,  1,  4, -1,  4, -1,  8,  4,  1,  0,  0,  4,  1,  7,  5,
#         4,  4,  1, -1,  1,  1,  1,  6,  4,  4,  1,  1,  1,  4,  4,  3,  0,
#         4,  2,  3,  4,  0,  4,  4,  1,  1,  7,  1,  4, -1,  1,  1,  8,  4,
#        -1,  4,  6,  1,  1,  1,  1,  1,  7,  0,  4,  4])

# %%
plt.scatter(x[:,0],x[:,1],c=db.labels_)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler

X, y = make_moons(n_samples=300, noise=0.05, random_state=42)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

dbscan = DBSCAN(eps=0.3, min_samples=5)
clusters = dbscan.fit_predict(X_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis', s=50)
plt.title('DBSCAN Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar(label='Cluster ID')
plt.show()

n_clusters_ = len(set(clusters)) - (1 if -1 in clusters else 0)
n_noise_ = list(clusters).count(-1)

print(f'Estimated number of clusters: {n_clusters_}')
print(f'Estimated number of noise points: {n_noise_}')

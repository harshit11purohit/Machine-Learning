# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=1000,n_targets=1,n_features=4,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=1)
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)
print(mean_squared_error(y_test,y_pred)),
print(r2_score(y_test,y_pred))
# Out:
# 308.1627947480963
# 0.9849259129936738

# %%
from sklearn.model_selection import GridSearchCV
gdr=GradientBoostingRegressor()
param_grid = {
    'n_estimators': [100, 200,300],
    'learning_rate': [0.01, 0.1, 1.0, 1.5, 2.0],
    #algorithm': ['SAMME']
}
clf=GridSearchCV(estimator=gdr,param_grid=param_grid,cv=5,verbose=3)
clf
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(mean_squared_error(y_test,y_pred)),
print(r2_score(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.616 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.635 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.633 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.616 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.664 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.807 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.828 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.832 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.812 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.840 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.888 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.902 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.906 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.889 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.907 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.969 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.970 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.978 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.973 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.976 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.975 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.975 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.982 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.979 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.981 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=0.977 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=0.976 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=0.984 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=0.981 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=0.982 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=0.908 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=0.906 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=0.924 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=0.862 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=0.924 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=0.909 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=0.901 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=0.921 total time=   0.1s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=0.871 total time=   0.1s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=0.926 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=300;, score=0.911 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, n_estimators=300;, score=0.902 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=300;, score=0.918 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=300;, score=0.880 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, n_estimators=300;, score=0.923 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, n_estimators=100;, score=0.660 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, n_estimators=100;, score=0.667 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, n_estimators=100;, score=0.609 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, n_estimators=100;, score=0.750 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, n_estimators=100;, score=0.642 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, n_estimators=200;, score=0.658 total time=   0.1s
# [CV 2/5] END learning_rate=1.5, n_estimators=200;, score=0.677 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, n_estimators=200;, score=0.583 total time=   0.1s
# [CV 4/5] END learning_rate=1.5, n_estimators=200;, score=0.744 total time=   0.1s
# [CV 5/5] END learning_rate=1.5, n_estimators=200;, score=0.646 total time=   0.1s
# [CV 1/5] END learning_rate=1.5, n_estimators=300;, score=0.659 total time=   0.1s
# [CV 2/5] END learning_rate=1.5, n_estimators=300;, score=0.687 total time=   0.1s
# [CV 3/5] END learning_rate=1.5, n_estimators=300;, score=0.590 total time=   0.1s
# [CV 4/5] END learning_rate=1.5, n_estimators=300;, score=0.750 total time=   0.1s
# [CV 5/5] END learning_rate=1.5, n_estimators=300;, score=0.663 total time=   0.2s
# [CV 1/5] END learning_rate=2.0, n_estimators=100;, score=-0.001 total time=   0.0s
# [CV 2/5] END learning_rate=2.0, n_estimators=100;, score=-0.016 total time=   0.0s
# [CV 3/5] END learning_rate=2.0, n_estimators=100;, score=-0.021 total time=   0.0s
# [CV 4/5] END learning_rate=2.0, n_estimators=100;, score=-0.009 total time=   0.0s
# [CV 5/5] END learning_rate=2.0, n_estimators=100;, score=-0.167 total time=   0.0s
# [CV 1/5] END learning_rate=2.0, n_estimators=200;, score=-0.001 total time=   0.1s
# [CV 2/5] END learning_rate=2.0, n_estimators=200;, score=-0.016 total time=   0.1s
# [CV 3/5] END learning_rate=2.0, n_estimators=200;, score=-0.021 total time=   0.1s
# [CV 4/5] END learning_rate=2.0, n_estimators=200;, score=-0.009 total time=   0.1s
# [CV 5/5] END learning_rate=2.0, n_estimators=200;, score=-0.167 total time=   0.1s
# [CV 1/5] END learning_rate=2.0, n_estimators=300;, score=-0.001 total time=   0.2s
# [CV 2/5] END learning_rate=2.0, n_estimators=300;, score=-0.016 total time=   0.2s
# [CV 3/5] END learning_rate=2.0, n_estimators=300;, score=-0.021 total time=   0.1s
# [CV 4/5] END learning_rate=2.0, n_estimators=300;, score=-0.009 total time=   0.1s
# [CV 5/5] END learning_rate=2.0, n_estimators=300;, score=-0.167 total time=   0.2s
# 244.5363451660569
# 0.9880382635215411

# %%
from sklearn.model_selection import RandomizedSearchCV
gdr=GradientBoostingRegressor()
param_ = {
    'n_estimators': [100, 200,300],
    'learning_rate': [0.01, 0.1, 1.0, 1.5, 2.0],
    #algorithm': ['SAMME']
}
clf=RandomizedSearchCV(estimator=gdr,param_distributions=param_,cv=5,verbose=3)
clf
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print(mean_squared_error(y_test,y_pred)),
print(r2_score(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END learning_rate=2.0, n_estimators=300;, score=-0.001 total time=   0.1s
# [CV 2/5] END learning_rate=2.0, n_estimators=300;, score=-0.016 total time=   0.2s
# [CV 3/5] END learning_rate=2.0, n_estimators=300;, score=-0.021 total time=   0.1s
# [CV 4/5] END learning_rate=2.0, n_estimators=300;, score=-0.009 total time=   0.1s
# [CV 5/5] END learning_rate=2.0, n_estimators=300;, score=-0.167 total time=   0.1s
# [CV 1/5] END learning_rate=1.5, n_estimators=200;, score=0.648 total time=   0.1s
# [CV 2/5] END learning_rate=1.5, n_estimators=200;, score=0.690 total time=   0.1s
# [CV 3/5] END learning_rate=1.5, n_estimators=200;, score=0.597 total time=   0.1s
# [CV 4/5] END learning_rate=1.5, n_estimators=200;, score=0.726 total time=   0.1s
# [CV 5/5] END learning_rate=1.5, n_estimators=200;, score=0.649 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.616 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.635 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.633 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.616 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.664 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.969 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.970 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.978 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.973 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.976 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.807 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.828 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.833 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.812 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.839 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=300;, score=0.908 total time=   0.1s
# [CV 2/5] END learning_rate=1.0, n_estimators=300;, score=0.906 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=300;, score=0.919 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=300;, score=0.867 total time=   0.1s
# [CV 5/5] END learning_rate=1.0, n_estimators=300;, score=0.923 total time=   0.1s
# [CV 1/5] END learning_rate=2.0, n_estimators=100;, score=-0.001 total time=   0.0s
# [CV 2/5] END learning_rate=2.0, n_estimators=100;, score=-0.016 total time=   0.0s
# [CV 3/5] END learning_rate=2.0, n_estimators=100;, score=-0.021 total time=   0.0s
# [CV 4/5] END learning_rate=2.0, n_estimators=100;, score=-0.009 total time=   0.0s
# [CV 5/5] END learning_rate=2.0, n_estimators=100;, score=-0.167 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=0.910 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=0.904 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=0.922 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=0.869 total time=   0.1s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=0.926 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.888 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.902 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.906 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.889 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.906 total time=   0.2s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=0.909 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=0.908 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=0.925 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=0.876 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=0.921 total time=   0.0s
# 308.94298797731693
# 0.9848877490724626

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

ada=GradientBoostingClassifier()
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0, 1.5, 2.0],
    #algorithm': ['SAMME']
}
x,y=make_classification(n_classes=2,n_samples=1000,n_features=20,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=1)
clf=GridSearchCV(estimator=ada,param_grid=param_grid,cv=5,verbose=3)
clf.fit(x_train,y_train)
y_pred=clf.best_estimator_.predict(x_test)
print(accuracy_score(y_test,y_pred)),
print(confusion_matrix(y_test,y_pred)),
print(classification_report(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=50;, score=0.871 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=50;, score=0.900 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=50;, score=0.836 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=50;, score=0.850 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=50;, score=0.821 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.857 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.907 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.857 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.821 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.857 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.893 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.864 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.836 total time=   0.5s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.829 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, n_estimators=50;, score=0.843 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, n_estimators=50;, score=0.914 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=50;, score=0.850 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=50;, score=0.857 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=50;, score=0.836 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.914 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.871 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.864 total time=   0.4s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.914 total time=   0.4s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.857 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.864 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.821 total time=   0.5s
# [CV 1/5] END learning_rate=1.0, n_estimators=50;, score=0.821 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, n_estimators=50;, score=0.850 total time=   0.1s
# [CV 3/5] END learning_rate=1.0, n_estimators=50;, score=0.821 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, n_estimators=50;, score=0.864 total time=   0.1s
# [CV 5/5] END learning_rate=1.0, n_estimators=50;, score=0.821 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, n_estimators=100;, score=0.843 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, n_estimators=100;, score=0.886 total time=   0.2s
# [CV 3/5] END learning_rate=1.0, n_estimators=100;, score=0.807 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 1/5] END learning_rate=1.0, n_estimators=200;, score=0.836 total time=   0.4s
# [CV 2/5] END learning_rate=1.0, n_estimators=200;, score=0.886 total time=   0.4s
# [CV 3/5] END learning_rate=1.0, n_estimators=200;, score=0.793 total time=   0.5s
# [CV 4/5] END learning_rate=1.0, n_estimators=200;, score=0.836 total time=   0.6s
# [CV 5/5] END learning_rate=1.0, n_estimators=200;, score=0.836 total time=   0.6s
# [CV 1/5] END learning_rate=1.5, n_estimators=50;, score=0.886 total time=   0.1s
# [CV 2/5] END learning_rate=1.5, n_estimators=50;, score=0.893 total time=   0.1s
# [CV 3/5] END learning_rate=1.5, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 4/5] END learning_rate=1.5, n_estimators=50;, score=0.814 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, n_estimators=50;, score=0.807 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, n_estimators=100;, score=0.879 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, n_estimators=100;, score=0.871 total time=   0.2s
# [CV 3/5] END learning_rate=1.5, n_estimators=100;, score=0.786 total time=   0.2s
# [CV 4/5] END learning_rate=1.5, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, n_estimators=100;, score=0.807 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, n_estimators=200;, score=0.821 total time=   0.4s
# [CV 2/5] END learning_rate=1.5, n_estimators=200;, score=0.886 total time=   0.6s
# [CV 3/5] END learning_rate=1.5, n_estimators=200;, score=0.821 total time=   0.6s
# [CV 4/5] END learning_rate=1.5, n_estimators=200;, score=0.843 total time=   0.4s
# [CV 5/5] END learning_rate=1.5, n_estimators=200;, score=0.807 total time=   0.6s
# [CV 1/5] END learning_rate=2.0, n_estimators=50;, score=0.350 total time=   0.1s
# [CV 2/5] END learning_rate=2.0, n_estimators=50;, score=0.186 total time=   0.1s
# [CV 3/5] END learning_rate=2.0, n_estimators=50;, score=0.821 total time=   0.1s
# [CV 4/5] END learning_rate=2.0, n_estimators=50;, score=0.814 total time=   0.1s
# [CV 5/5] END learning_rate=2.0, n_estimators=50;, score=0.764 total time=   0.1s
# [CV 1/5] END learning_rate=2.0, n_estimators=100;, score=0.350 total time=   0.2s
# [CV 2/5] END learning_rate=2.0, n_estimators=100;, score=0.593 total time=   0.2s
# [CV 3/5] END learning_rate=2.0, n_estimators=100;, score=0.764 total time=   0.3s
# [CV 4/5] END learning_rate=2.0, n_estimators=100;, score=0.779 total time=   0.3s
# [CV 5/5] END learning_rate=2.0, n_estimators=100;, score=0.764 total time=   0.3s
# [CV 1/5] END learning_rate=2.0, n_estimators=200;, score=0.350 total time=   0.5s
# [CV 2/5] END learning_rate=2.0, n_estimators=200;, score=0.186 total time=   0.5s
# [CV 3/5] END learning_rate=2.0, n_estimators=200;, score=0.843 total time=   0.6s
# [CV 4/5] END learning_rate=2.0, n_estimators=200;, score=0.800 total time=   0.4s
# [CV 5/5] END learning_rate=2.0, n_estimators=200;, score=0.786 total time=   0.5s
# 0.8533333333333334
# [[122  17]
#  [ 27 134]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       139
#            1       0.89      0.83      0.86       161
#
#     accuracy                           0.85       300
#    macro avg       0.85      0.85      0.85       300
# weighted avg       0.86      0.85      0.85       300

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8533333333333334

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 200}

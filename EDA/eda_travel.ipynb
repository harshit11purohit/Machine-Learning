# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# !pip install plotly
import warnings
warnings.filterwarnings('ignore')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df = pd.read_csv("C:/Users/Jagdish singh/projects/datasets/Travel.csv")

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.isnull().sum()
df.columns
df.size
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.Gender.unique()
df.Gender=df.Gender.replace('Fe Male','Female')
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# DurationOfPitch             251
# MonthlyIncome               233
# Age                         226
# NumberOfTrips               140
# NumberOfChildrenVisiting     66
# NumberOfFollowups            45
# PreferredPropertyStar        26
# TypeofContact                25
# CustomerID                    0
# ProdTaken                     0
# Gender                        0
# CityTier                      0
# ProductPitched                0
# NumberOfPersonVisiting        0
# Occupation                    0
# MaritalStatus                 0
# PitchSatisfactionScore        0
# Passport                      0
# OwnCar                        0
# Designation                   0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4128 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4128 non-null   int64
#  1   ProdTaken                 4128 non-null   int64
#  2   Age                       4128 non-null   float64
#  3   TypeofContact             4128 non-null   object
#  4   CityTier                  4128 non-null   int64
#  5   DurationOfPitch           4128 non-null   float64
#  6   Occupation                4128 non-null   object
#  7   Gender                    4128 non-null   object
#  8   NumberOfPersonVisiting    4128 non-null   int64
#  9   NumberOfFollowups         4128 non-null   float64
#  10  ProductPitched            4128 non-null   object
#  11  PreferredPropertyStar     4128 non-null   float64
#  12  MaritalStatus             4128 non-null   object
# ...

# %%
cats = ['ProdTaken', 'CityTier', 'PreferredPropertyStar', 'Passport',
        'OwnCar', 'PitchSatisfactionScore', 'TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
        'MaritalStatus', 'Designation']
nums = ['CustomerID', 'Age', 'DurationOfPitch',
       'NumberOfPersonVisiting', 'NumberOfFollowups',
       'NumberOfTrips',
       'NumberOfChildrenVisiting', 'MonthlyIncome']

# %%
#univaraite analysis for categorical

# %%
x=df.MaritalStatus.value_counts()
plt.pie(x,data =df ,autopct='%1.2f%%',startangle=90)
plt.show()

# %%
x1=df.Gender.value_counts()
y1=df.Gender
sns.barplot(x1)
plt.show()
x1
# Out:
# Gender
# Male      2463
# Female    1665
# Name: count, dtype: int64

# %%
sns.countplot(
    x='MaritalStatus',
    hue='ProdTaken',
    data=df
)
plt.title("Product Taken vs Marital Status")
plt.show()

# %%
x2=df.ProdTaken.value_counts()
sns.barplot(x2)
plt.show()

# %%
sns.countplot(
    x='ProdTaken',
    hue='Gender',
    data=df
)
plt.title("Product Taken by Gender")
plt.show()

# %%
for cat_column in cats:
    plt.Figure(figsize=(8,5))
    sns.countplot(x=cat_column,data=df,palette='viridis')
    plt.title(f"analysis of -{cat_column}")
    plt.show()

# %%
#analysis for  numerical column

# %%
#Designed for continuous or discrete numerical data.
for num in nums:
    plt.Figure(figsize=(8,15))
    sns.histplot(df[num],kde=True,color='pink')
    plt.title(f"nums name is -{num}")
    plt.show()

# %%
df.columns
df.Age.isnull().sum()
sns.histplot(df.Age,bins=40,kde=True)
plt.show()

# %%
sns.countplot(x=df['TypeofContact'])
plt.show()

# %%
 for i in cats:
     print(f" {i} :{df[i].unique()}")
# Out:
#  ProdTaken :[1 0]
#  CityTier :[3 1 2]
#  PreferredPropertyStar :[3. 4. 5.]
#  Passport :[1 0]
#  OwnCar :[1 0]
#  PitchSatisfactionScore :[2 3 5 4 1]
#  TypeofContact :['Self Enquiry' 'Company Invited']
#  Occupation :['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
#  Gender :['Female' 'Male']
#  ProductPitched :['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
#  MaritalStatus :['Single' 'Divorced' 'Married' 'Unmarried']
#  Designation :['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
# bivariate analysis
df.DurationOfPitch
# Out:
# 0        6.0
# 1       14.0
# 2        8.0
# 3        9.0
# 5        8.0
#         ...
# 4883     9.0
# 4884    31.0
# 4885    17.0
# 4886    16.0
# 4887    14.0
# Name: DurationOfPitch, Length: 4128, dtype: float64

# %%
sns.scatterplot(x='Age',y='DurationOfPitch',data=df,hue='ProdTaken',palette='coolwarm')
plt.show()

# %%
df.MaritalStatus.unique()
df.ProdTaken.unique()
# Out:
# array([1, 0])

# %%
sns.barplot(x=df['MaritalStatus'],y=df['ProdTaken'],data=df,hue='Gender')
plt.show()

# %%
x4=df.groupby('MaritalStatus')['ProdTaken'].value_counts().reset_index()
x4
# Out:
#   MaritalStatus  ProdTaken  count
# 0      Divorced          0    684
# 1      Divorced          1    105
# 2       Married          0   1707
# 3       Married          1    283
# 4        Single          0    424
# 5        Single          1    243
# 6     Unmarried          0    516
# 7     Unmarried          1    166

# %%
pd.crosstab(df.MaritalStatus,df.ProdTaken)
# Out:
# ProdTaken         0    1
# MaritalStatus
# Divorced        684  105
# Married        1707  283
# Single          424  243
# Unmarried       516  166

# %%
table = df.groupby(['MaritalStatus', 'ProdTaken']).size().reset_index(name='Count')
table
# Out:
#   MaritalStatus  ProdTaken  Count
# 0      Divorced          0    684
# 1      Divorced          1    105
# 2       Married          0   1707
# 3       Married          1    283
# 4        Single          0    424
# 5        Single          1    243
# 6     Unmarried          0    516
# 7     Unmarried          1    166

# %%
table = (
    df.groupby(['MaritalStatus', 'ProdTaken'])
      .size().unstack(fill_value=0)
      
)
table
# Out:
# ProdTaken         0    1
# MaritalStatus
# Divorced        684  105
# Married        1707  283
# Single          424  243
# Unmarried       516  166

# %%
table = pd.crosstab(df['MaritalStatus'], df['ProdTaken'])
table
# Out:
# ProdTaken         0    1
# MaritalStatus
# Divorced        684  105
# Married        1707  283
# Single          424  243
# Unmarried       516  166

# %%
table.plot(kind='bar',stacked=True,color=['skyblue','pink'])
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
table = df.groupby(['MaritalStatus', 'ProdTaken']).size().reset_index(name='Count')
table
# Out:
#   MaritalStatus  ProdTaken  Count
# 0      Divorced          0    684
# 1      Divorced          1    105
# 2       Married          0   1707
# 3       Married          1    283
# 4        Single          0    424
# 5        Single          1    243
# 6     Unmarried          0    516
# 7     Unmarried          1    166

# %%
sns.barplot(x = 'ProductPitched', y = 'PitchSatisfactionScore', data=df, palette = 'coolwarm')
# Out:
# <Axes: xlabel='ProductPitched', ylabel='PitchSatisfactionScore'>

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
sns.lineplot(x='NumberOfFollowups',y='PitchSatisfactionScore', data=df,markers='o')
plt.show()

# %%
#multivariate analysis

# %%
sns.violinplot(x='ProdTaken',y='Age',data=df)
plt.show()

# %%
sns.swarmplot(x='Gender',y='Age',data=df,hue='ProdTaken')
plt.show()

# %%
#3D plots

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(12,8))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(df['Age'],df['MonthlyIncome'],df['DurationOfPitch'],c=df['ProdTaken'])
ax.set_xlabel("Age")
ax.set_ylabel("monthly income")
ax.set_zlabel("duration of pitch")
plt.show()

# %%
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
numeric_cols=df.select_dtypes(include='number')
sns.heatmap(numeric_cols.corr())
numeric_cols
# Out:
#       CustomerID  ProdTaken   Age  CityTier  DurationOfPitch  \
# 0         200000          1  41.0         3              6.0
# 1         200001          0  49.0         1             14.0
# 2         200002          1  37.0         1              8.0
# 3         200003          0  33.0         1              9.0
# 5         200005          0  32.0         1              8.0
# ...          ...        ...   ...       ...              ...
# 4883      204883          1  49.0         3              9.0
# 4884      204884          1  28.0         1             31.0
# 4885      204885          1  52.0         3             17.0
# 4886      204886          1  19.0         3             16.0
# 4887      204887          1  36.0         1             14.0
#
#       NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# 0                          3                3.0                    3.0
# 1                          3                4.0                    4.0
# ...

# %%
#feature engineering
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
#total visit = no of children + no of students 
df["total_visiting"]=df.NumberOfChildrenVisiting  + df.NumberOfPersonVisiting
df.drop('NumberOfChildrenVisiting',inplace=True,axis=1)

# %%
number_features= [x5 for x5 in df.columns if df[x5].dtype != 'O']
print("no of features are:", len(number_features))
number_features
# Out:
# no of features are: 14
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'MonthlyIncome',
#  'total_visiting']

# %%
numy_cols=df.select_dtypes(include='number')
numy_cols.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'CityTier', 'DurationOfPitch',
#        'NumberOfPersonVisiting', 'NumberOfFollowups', 'PreferredPropertyStar',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'MonthlyIncome', 'total_visiting'],
#       dtype='object')

# %%
caty_cols=df.select_dtypes(exclude='number')
caty_cols.columns
# Out:
# Index(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')

# %%
# train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('MonthlyIncome', axis=1)  # all columns except MonthlyIncome
y = df['MonthlyIncome']               # target column

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1
)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3302, 19) (826, 19) (3302,) (826,)

# %%
X_train
X_test
y_test
y_train
# Out:
# 3444    21628.0
# 4355    20771.0
# 1374    32875.0
# 4432    22706.0
# 603     17274.0
#          ...
# 3535    22998.0
# 3386    25772.0
# 1160    20770.0
# 4717    21657.0
# 289     18310.0
# Name: MonthlyIncome, Length: 3302, dtype: float64

# %%
""" data is either categorical , numerical
 but for model building all dataa should be converteed into number 
using model encoding"""
# Out:
# ' data is either categorical , numerical\n but for model building all dataa should be converteed into number \nusing model encoding'

# %%
cat_features=X.select_dtypes(include='object').columns
cat_features
# Out:
# Index(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')

# %%
num_features= X.select_dtypes(exclude='object').columns
number_features
#x is a  df without monthly income column
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'MonthlyIncome',
#  'total_visiting']

# %%
#scaling  for numerical data
# one hot encoding or label coding for catergorical data

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

# %%
# colum tranforme applies tranformation to column of arrat or pandas or df

# %%
numeric_transformer =StandardScaler()
oh_transformer=OneHotEncoder(drop='first')
preprocessor=ColumnTransformer([
    
    ( 'OneHotEncoder',oh_transformer,cat_features),
    ('StandardScaler',numeric_transformer,number_features )  
])

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'Designation', 'MonthlyIncome', 'total_visiting'],
#       dtype='object')

# %%
newcat_col=df.select_dtypes(include='object')
x5=newcat_col.columns.tolist()

# %%
x5
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
newnum_col=df.select_dtypes(exclude='object')
y5=newnum_col.columns.tolist()

# %%
y5
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'MonthlyIncome',
#  'total_visiting']

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'Designation', 'MonthlyIncome', 'total_visiting'],
#       dtype='object')

# %%
b=df['NumberOfTrips']
a=df.drop('NumberOfTrips',axis=1)
b
a
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
a_train,a_test,b_train,b_test=train_test_split(a,b,train_size=0.2,random_state=1)
a_test,
a_train,
b_train,
b_test
# Out:
# 153     1.0
# 4135    8.0
# 516     3.0
# 2626    3.0
# 907     1.0
#        ...
# 445     4.0
# 3770    2.0
# 4408    3.0
# 1993    2.0
# 2662    8.0
# Name: NumberOfTrips, Length: 3303, dtype: float64

# %%
a_test.shape,a_train.shape,b_train.shape,b_test.shape
# Out:
# ((3303, 19), (825, 19), (825,), (3303,))

# %%
ohe=OneHotEncoder(drop='first')
stsc=StandardScaler()
data=ColumnTransformer([
    ('OneHotEncoder',ohe,x5 ),
    ('StandardScaler',stsc,y5)
])

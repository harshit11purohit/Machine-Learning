# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
t=np.random.randint(1,100,50)
t
# Out:
# array([79, 34, 29, 68, 85, 69, 68,  6, 52, 87,  3, 86, 69, 77, 19, 83, 92,
#         1, 22, 90, 47, 67, 53, 18,  7, 97, 84, 64, 22, 95, 16,  1, 50, 44,
#        76, 64, 38, 55, 54, 91,  8, 89, 33,  6, 53, 22, 50, 84, 15, 60],
#       dtype=int32)

# %%
plt.figure(figsize=(8, 5))
x=np.random.normal(loc=1,scale=2,size=100)
sns.histplot(x,kde=True,bins=20)
plt.show()



t= np.random.normal(loc=1, scale=2, size=100)
plt.figure(figsize=(8, 5))
sns.histplot(t, kde=True, bins=20)

# 

plt.show()

# %%
#

# %%
a = np.random.uniform(low=2, high=4, size=100)
plt.figure(figsize=(8, 5))
sns.histplot(
    a,
    bins=15,
    kde=True,
    stat="density",   # Important for KDE comparison
    edgecolor="black"
)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Reproducibility
np.random.seed(42)

# Generate data
uniform_data = np.random.uniform(low=2, high=4, size=1000)
normal_data = np.random.normal(loc=3, scale=0.6, size=1000)

# Plot
plt.figure(figsize=(10, 5))

# Uniform Distribution
sns.histplot(
    uniform_data,
    kde=True,
    stat="density",
    bins=20,
    label="Uniform",
    edgecolor="black"
)

# Normal Distribution
sns.histplot(
    normal_data,
    kde=True,
    stat="density",
    bins=20,
    label="Normal",
    edgecolor="black",
    alpha=0.6
)

plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Uniform vs Normal Distribution")
plt.legend()
plt.show()

# %%
np.random.seed(42)
# Generate sufficient samples
x = np.random.chisquare(df=30, size=1000)
plt.figure(figsize=(8, 5))
sns.histplot(
    x,
    kde=True,
    bins=30,
    stat="density",
    edgecolor="black"
)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Chi-Square Distribution (df = 30)")
plt.show()

# %%
y=np.random.poisson(lam=5,size=100)
sns.histplot(y,kde=True)
plt.show()

# %%
x=np.linspace(2,5,100)
x
# Out:
# array([2.        , 2.03030303, 2.06060606, 2.09090909, 2.12121212,
#        2.15151515, 2.18181818, 2.21212121, 2.24242424, 2.27272727,
#        2.3030303 , 2.33333333, 2.36363636, 2.39393939, 2.42424242,
#        2.45454545, 2.48484848, 2.51515152, 2.54545455, 2.57575758,
#        2.60606061, 2.63636364, 2.66666667, 2.6969697 , 2.72727273,
#        2.75757576, 2.78787879, 2.81818182, 2.84848485, 2.87878788,
#        2.90909091, 2.93939394, 2.96969697, 3.        , 3.03030303,
#        3.06060606, 3.09090909, 3.12121212, 3.15151515, 3.18181818,
#        3.21212121, 3.24242424, 3.27272727, 3.3030303 , 3.33333333,
#        3.36363636, 3.39393939, 3.42424242, 3.45454545, 3.48484848,
#        3.51515152, 3.54545455, 3.57575758, 3.60606061, 3.63636364,
#        3.66666667, 3.6969697 , 3.72727273, 3.75757576, 3.78787879,
#        3.81818182, 3.84848485, 3.87878788, 3.90909091, 3.93939394,
#        3.96969697, 4.        , 4.03030303, 4.06060606, 4.09090909,
# ...

# %%
import statistics as se
c=np.random.randint(1,5,100)
y=se.pvariance(c)
y
# Out:
# np.int32(1)
